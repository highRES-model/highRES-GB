# %%
import os
import sys
topFolder = os.getcwd().split('\\').pop(-1)
moduleDirectory = os.getcwd()[:-len(topFolder)]
sys.path.append(moduleDirectory)
from IPython.display import Image
from reporting import *
py.offline.init_notebook_mode(connected=True) #imports plotly.js to the notebook
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
path = r'C:\Users\ucqba01\Documents\Local Data\Round 6'

imageFile = plotComparisonCorrelationHeatmaps(10000,
                                              path,
                                              [20, 40, 60, 80, 90],
                                              [80, 100, 120, 140],
                                              'hR_m_2002_waves(waves)_RPS(rps)_fcost(fcost)_newfuelcost.db',
                                              'VRE Generation National Correlation')

print('location',imageFile)
Image(filename=imageFile)
# Out:
# location C:\Users\ucqba01\Documents\Local Data\Round 6\compare\correlations.png
